# %%
# Actividad

# %%
# 1.- Crea una tupla con una longitud de 5 usando diferentes tipos de datos.
t = ("Brandon",23,1.83,7+5j,True) 
type(t)
# Out:
# tuple

# %%
# 2.- Cambiar de tupla a lista.
t_lista = list(t)
t_lista
# Out:
# ['Brandon', 23, 1.83, (7+5j), True]

# %%
type(t_lista)
# Out:
# list

# %%
type(t)
# Out:
# tuple

# %%
# 3.- Crea un diccionario donde la clave sea del 1 al 5 y los elementos los datos de la lista.
# Utilizar función "list"
diccionario={1:t_lista[0],
             2:t_lista[1],
             3:t_lista[2],
             4:t_lista[3],
             5:t_lista[4]}
diccionario
# Out:
# {1: 'Brandon', 2: 23, 3: 1.83, 4: (7+5j), 5: True}
